# %%
import pandas as pd

# %%
year = ['2017','2018']
place = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']

# %%
for y in year:
    for p in place:
        df = pd.read_excel('구별_시간별_교통사고/{0}/{0}_{1}.xlsx'.format(y,p))
        print('{0}_{1} 데이터 총 {2}개의 데이터를 가져왔습니다.'.format(y,p,len(df)))
# Out:
# 2017_강남구 데이터 총 3467개의 데이터를 가져왔습니다.
# 2017_강동구 데이터 총 1371개의 데이터를 가져왔습니다.
# 2017_강북구 데이터 총 1202개의 데이터를 가져왔습니다.
# 2017_강서구 데이터 총 1584개의 데이터를 가져왔습니다.
# 2017_관악구 데이터 총 1251개의 데이터를 가져왔습니다.
# 2017_광진구 데이터 총 1064개의 데이터를 가져왔습니다.
# 2017_구로구 데이터 총 1433개의 데이터를 가져왔습니다.
# 2017_금천구 데이터 총 824개의 데이터를 가져왔습니다.
# 2017_노원구 데이터 총 1499개의 데이터를 가져왔습니다.
# 2017_도봉구 데이터 총 944개의 데이터를 가져왔습니다.
# 2017_동대문구 데이터 총 1718개의 데이터를 가져왔습니다.
# 2017_동작구 데이터 총 1410개의 데이터를 가져왔습니다.
# 2017_마포구 데이터 총 1859개의 데이터를 가져왔습니다.
# 2017_서대문구 데이터 총 1032개의 데이터를 가져왔습니다.
# 2017_서초구 데이터 총 2362개의 데이터를 가져왔습니다.
# 2017_성동구 데이터 총 1076개의 데이터를 가져왔습니다.
# 2017_성북구 데이터 총 1557개의 데이터를 가져왔습니다.
# 2017_송파구 데이터 총 2758개의 데이터를 가져왔습니다.
# 2017_양천구 데이터 총 1343개의 데이터를 가져왔습니다.
# 2017_영등포구 데이터 총 2386개의 데이터를 가져왔습니다.
# 2017_용산구 데이터 총 1337개의 데이터를 가져왔습니다.
# 2017_은평구 데이터 총 1067개의 데이터를 가져왔습니다.
# 2017_종로구 데이터 총 1190개의 데이터를 가져왔습니다.
# 2017_중구 데이터 총 1252개의 데이터를 가져왔습니다.
# 2017_중랑구 데이터 총 1639개의 데이터를 가져왔습니다.
# 2018_강남구 데이터 총 3459개의 데이터를 가져왔습니다.
# 2018_강동구 데이터 총 1418개의 데이터를 가져왔습니다.
# ...

# %%
pd.read_csv('도로별_시간별_차량통행속도/2017/2017년 1월 통행속도.csv', encoding='cp949')
# Out:
#               일자 요일    도로명       링크아이디         시점명         종점명  방향    거리  \
# 0       20170101  일  4.19로  1080012200     아카데미하우스    국립4.19묘지  상행  1179
# 1       20170101  일  4.19로  1080012800    국립4.19묘지  국립4.19묘지입구  상행   352
# 2       20170101  일  4.19로  1080012700  국립4.19묘지입구    국립4.19묘지  하행   354
# 3       20170101  일  4.19로  1080012100    국립4.19묘지     아카데미하우스  하행  1190
# 4       20170101  일    가락로  1230024700        방이초교      방이동고분군  상행   844
# ...          ... ..    ...         ...         ...         ...  ..   ...
# 147442  20170131  화    휘경로  1050019700        외대앞역     이경시장삼거리  상행   364
# 147443  20170131  화    휘경로  1050019800     이경시장삼거리        외대앞역  하행   364
# 147444  20170131  화    휘경로  1050020200        외대앞역        외국어대  하행   434
# 147445  20170131  화   희우정로  1130016400      망원정사거리      한강공원입구  상행   692
# 147446  20170131  화   희우정로  1130016300      한강공원입구      망원정사거리  하행   688
#
#           01시    02시  ...    16시    17시    18시    19시    20시    21시    22시  \
# ...
