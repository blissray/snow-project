# %%
import pandas as pd

# %%
# df = pd.read_excel('구별_일별_기상관측_2017.xlsx')
df = pd.read_csv('서울시_일별_기상관측_2017.csv')
# df = pd.read_csv('서울시_시간별_기상관측_2018.csv', encoding='cp949')

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#                    날짜  평균  기온  최고  기온  최저  기온 강수량(mm) 신적설(cm)  평균  풍속(m/s)  \
# 0    2017년 01월01일 (일)     2.7     6.9    -1.6       -       -          1.6
# 1    2017년 01월02일 (월)     5.0     9.2     1.8     0.3       -          2.2
# 2    2017년 01월03일 (화)     2.0     7.7    -2.3       -       -          1.9
# 3    2017년 01월04일 (수)     3.9     8.9     1.0       -       -          1.7
# 4    2017년 01월05일 (목)     3.8     7.3    -0.1       -       -          3.2
# ..                ...     ...     ...     ...     ...     ...          ...
# 360  2017년 12월27일 (수)    -6.9    -2.6   -10.3       -       -          1.9
# 361  2017년 12월28일 (목)    -2.1     0.8    -6.8     0.0       -          1.3
# 362  2017년 12월29일 (금)     2.1     6.0    -0.4     0.0       -          1.2
# 363  2017년 12월30일 (토)     1.4     4.5    -1.2     0.7     0.2          1.0
# 364  2017년 12월31일 (일)    -0.3     3.3    -3.2     1.0     1.0          2.3
#
#      평균  습도  (%)  운량(1/10)  일조  시간  (Hr)              날씨
# ...
