# %%
import pandas as pd

# %%
기상 = pd.read_csv('../데이터정리/기상.csv')
교통 = pd.read_csv('../데이터정리/교통.csv')

# %%
전체 = pd.merge(기상,교통, how='outer')

# %%
전체.head()
# Out:
#            날짜     년  월  일  시  구이름  기온(°C)  강수량(mm)       날씨          날씨_리스트  \
# 0  2017-01-01  2017  1  1  0  강남구     1.7      0.0  구름많음/안개  ['구름많음', '안개']
# 1  2017-01-01  2017  1  1  1  강남구     1.4      0.0  구름많음/안개  ['구름많음', '안개']
# 2  2017-01-01  2017  1  1  2  강남구     1.2      0.0  구름많음/안개  ['구름많음', '안개']
# 3  2017-01-01  2017  1  1  3  강남구     0.5      0.0  구름많음/안개  ['구름많음', '안개']
# 4  2017-01-01  2017  1  1  4  강남구     0.6      0.0  구름많음/안개  ['구름많음', '안개']
#
#    강설량_체크  계산된적설량(cm)  교통사고수     차량통행속도     교통량
# 0   False         0.0    0.0  36.298658  1708.4
# 1   False         0.0    0.0  34.514040  1815.7
# 2   False         0.0    1.0  35.041178  1104.1
# 3   False         0.0    2.0  37.128855   844.3
# 4   False         0.0    1.0  38.630438   759.3

# %%
전체.to_csv('../데이터정리/전체데이터.csv', index=False)
